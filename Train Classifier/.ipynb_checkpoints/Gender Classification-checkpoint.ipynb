# %% [markdown]
# ### Specifying Paths for the data to be loaded

# %%
import os

# %%
train_path = './gender_dataset_face/Train/'
validate_path = './gender_dataset_face/Validate/'

# %% [markdown]
# ### Folder Structure
#  >  gender_dataset_face
#  -     |
#  -     |->Train
#  - -         |
#  - -         |->man
#  - -         |->woman
#  - -     |
#  -     |->Validate
#  - -         |
#  - -         |->man
#  - -         |->woman
#  - -     |
#  -     |->Test

# %%
#Printing the number of files in Train and Validation set

print('Number of images of MAN in Train set:',len(os.listdir(train_path+'man/')))
print('Number of images of WOMAN in Train set:',len(os.listdir(train_path+'woman/')))
print('Number of images of MAN in Validate set:',len(os.listdir(validate_path+'man/')))
print('Number of images of WOMAN in Validate set:',len(os.listdir(validate_path+'woman/')))
# Out:
# Number of images of MAN in Train set: 1071
# Number of images of WOMAN in Train set: 1032
# Number of images of MAN in Validate set: 100
# Number of images of WOMAN in Validate set: 100

# %% [markdown]
# ### Defining Model

# %%
import keras
from keras.models import Sequential
from keras.layers import Flatten, Activation, Dense, Conv2D, MaxPooling2D, Dropout, BatchNormalization
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
IMG_SIZE = 150

model = Sequential(name = 'Gender_classifier')
model.add(Conv2D(16, (3,3), input_shape=(IMG_SIZE, IMG_SIZE, 3)))
#model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(2,2))
#model.add(Dropout(0.1))

model.add(Conv2D(32, (3,3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.1))

model.add(Conv2D(64, (3,3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))

'''model.add(Conv2D(128, (3,3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.5))'''

model.add(Flatten())
#model.add(Dropout(0.5))
model.add(Dense(10, activation='relu'))


model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "Gender_classifier"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 148, 148, 16)      448
# _________________________________________________________________
# activation_1 (Activation)    (None, 148, 148, 16)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 72, 72, 32)        4640
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 72, 72, 32)        128
# _________________________________________________________________
# activation_2 (Activation)    (None, 72, 72, 32)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 34, 34, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 34, 34, 64)        256
# _________________________________________________________________
# activation_3 (Activation)    (None, 34, 34, 64)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18496)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                184970
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 208,949
# Trainable params: 208,757
# Non-trainable params: 192
# _________________________________________________________________

# %%
model.compile(loss = 'binary_crossentropy',
             optimizer=Adam(lr=0.0001, decay=0.00002),
             metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
# Creating ImageDataGenerator object for importing the data

from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1/255)
validation_datagen = ImageDataGenerator(rescale=1/255)

train_generator = train_datagen.flow_from_directory(train_path,
                                                   target_size=(IMG_SIZE, IMG_SIZE),
                                                   batch_size=64,
                                                   class_mode='binary')

validation_generator = validation_datagen.flow_from_directory(validate_path,
                                                   target_size=(IMG_SIZE, IMG_SIZE),
                                                   batch_size=16,
                                                   class_mode='binary')
# Out:
# Found 2103 images belonging to 2 classes.
# Found 200 images belonging to 2 classes.

# %%
#Training the model and storing results in history file

history = model.fit_generator(train_generator,
                             steps_per_epoch=(1071+1032)//64,
                             epochs=40,
                             validation_data=validation_generator,
                             validation_steps=200//16)
# Out:
# Epoch 1/40
# 32/32 [==============================] - 20s 629ms/step - loss: 0.6001 - accuracy: 0.6734 - val_loss: 0.6462 - val_accuracy: 0.5052
# Epoch 2/40
# 32/32 [==============================] - 14s 424ms/step - loss: 0.4461 - accuracy: 0.7818 - val_loss: 0.6574 - val_accuracy: 0.6141
# Epoch 3/40
# 32/32 [==============================] - 14s 422ms/step - loss: 0.3444 - accuracy: 0.8470 - val_loss: 0.6130 - val_accuracy: 0.5326
# Epoch 4/40
# 32/32 [==============================] - 14s 423ms/step - loss: 0.3110 - accuracy: 0.8701 - val_loss: 0.6159 - val_accuracy: 0.6793
# Epoch 5/40
# 32/32 [==============================] - 14s 424ms/step - loss: 0.2669 - accuracy: 0.8887 - val_loss: 0.5426 - val_accuracy: 0.7880
# Epoch 6/40
# 32/32 [==============================] - 14s 425ms/step - loss: 0.2306 - accuracy: 0.9014 - val_loss: 0.5008 - val_accuracy: 0.6467
# Epoch 7/40
# 32/32 [==============================] - 13s 417ms/step - loss: 0.1910 - accuracy: 0.9271 - val_loss: 0.6274 - val_accuracy: 0.7500
# Epoch 8/40
# 32/32 [==============================] - 13s 421ms/step - loss: 0.1907 - accuracy: 0.9259 - val_loss: 0.4735 - val_accuracy: 0.8315
# Epoch 9/40
# 32/32 [==============================] - 13s 420ms/step - loss: 0.1705 - accuracy: 0.9292 - val_loss: 0.4125 - val_accuracy: 0.7391
# Epoch 10/40
# 32/32 [==============================] - 13s 416ms/step - loss: 0.1620 - accuracy: 0.9377 - val_loss: 0.7039 - val_accuracy: 0.7500
# Epoch 11/40
# 32/32 [==============================] - 13s 417ms/step - loss: 0.1403 - accuracy: 0.9514 - val_loss: 0.2627 - val_accuracy: 0.8913
# Epoch 12/40
# 32/32 [==============================] - 13s 414ms/step - loss: 0.1332 - accuracy: 0.9522 - val_loss: 0.2985 - val_accuracy: 0.9130
# Epoch 13/40
# 32/32 [==============================] - 13s 414ms/step - loss: 0.1246 - accuracy: 0.9512 - val_loss: 0.0870 - val_accuracy: 0.9185
# Epoch 14/40
# 32/32 [==============================] - 13s 413ms/step - loss: 0.1061 - accuracy: 0.9598 - val_loss: 0.2193 - val_accuracy: 0.9062
# Epoch 15/40
# 32/32 [==============================] - 14s 425ms/step - loss: 0.1161 - accuracy: 0.9613 - val_loss: 0.2372 - val_accuracy: 0.9293
# Epoch 16/40
# 32/32 [==============================] - 14s 423ms/step - loss: 0.1075 - accuracy: 0.9571 - val_loss: 0.1589 - val_accuracy: 0.9185
# Epoch 17/40
# 32/32 [==============================] - 14s 425ms/step - loss: 0.0956 - accuracy: 0.9688 - val_loss: 0.1459 - val_accuracy: 0.9185
# Epoch 18/40
# 32/32 [==============================] - 13s 422ms/step - loss: 0.0913 - accuracy: 0.9685 - val_loss: 0.1393 - val_accuracy: 0.9457
# Epoch 19/40
# 32/32 [==============================] - 13s 421ms/step - loss: 0.0782 - accuracy: 0.9771 - val_loss: 0.0904 - val_accuracy: 0.8859
# Epoch 20/40
# 32/32 [==============================] - 13s 417ms/step - loss: 0.0755 - accuracy: 0.9773 - val_loss: 0.0568 - val_accuracy: 0.9402
# Epoch 21/40
# 32/32 [==============================] - 13s 419ms/step - loss: 0.0765 - accuracy: 0.9751 - val_loss: 0.0522 - val_accuracy: 0.9457
# Epoch 22/40
# 32/32 [==============================] - 13s 419ms/step - loss: 0.0738 - accuracy: 0.9760 - val_loss: 0.0718 - val_accuracy: 0.9402
# Epoch 23/40
# 32/32 [==============================] - 13s 414ms/step - loss: 0.0660 - accuracy: 0.9813 - val_loss: 0.1659 - val_accuracy: 0.9239
# Epoch 24/40
# 32/32 [==============================] - 13s 416ms/step - loss: 0.0643 - accuracy: 0.9819 - val_loss: 0.0707 - val_accuracy: 0.9348
# Epoch 25/40
# 32/32 [==============================] - 13s 418ms/step - loss: 0.0573 - accuracy: 0.9829 - val_loss: 0.0775 - val_accuracy: 0.9511
# Epoch 26/40
# 32/32 [==============================] - 13s 413ms/step - loss: 0.0635 - accuracy: 0.9809 - val_loss: 0.0035 - val_accuracy: 0.9402
# Epoch 27/40
# 32/32 [==============================] - 13s 413ms/step - loss: 0.0532 - accuracy: 0.9838 - val_loss: 0.2504 - val_accuracy: 0.9479
# Epoch 28/40
# 32/32 [==============================] - 14s 429ms/step - loss: 0.0539 - accuracy: 0.9838 - val_loss: 0.1362 - val_accuracy: 0.9402
# Epoch 29/40
# 32/32 [==============================] - 14s 426ms/step - loss: 0.0557 - accuracy: 0.9808 - val_loss: 0.0644 - val_accuracy: 0.9565
# Epoch 30/40
# 32/32 [==============================] - 14s 430ms/step - loss: 0.0501 - accuracy: 0.9868 - val_loss: 0.1256 - val_accuracy: 0.9457
# Epoch 31/40
# 32/32 [==============================] - 14s 425ms/step - loss: 0.0488 - accuracy: 0.9858 - val_loss: 0.1531 - val_accuracy: 0.9565
# Epoch 32/40
# 32/32 [==============================] - 14s 422ms/step - loss: 0.0411 - accuracy: 0.9907 - val_loss: 0.0039 - val_accuracy: 0.9511
# Epoch 33/40
# 32/32 [==============================] - 14s 425ms/step - loss: 0.0397 - accuracy: 0.9897 - val_loss: 0.1315 - val_accuracy: 0.9402
# Epoch 34/40
# 32/32 [==============================] - 13s 420ms/step - loss: 0.0398 - accuracy: 0.9892 - val_loss: 0.0117 - val_accuracy: 0.9620
# Epoch 35/40
# 32/32 [==============================] - 13s 418ms/step - loss: 0.0411 - accuracy: 0.9892 - val_loss: 0.1781 - val_accuracy: 0.9239
# Epoch 36/40
# 32/32 [==============================] - 14s 423ms/step - loss: 0.0366 - accuracy: 0.9922 - val_loss: 0.0774 - val_accuracy: 0.9620
# Epoch 37/40
# 32/32 [==============================] - 13s 416ms/step - loss: 0.0326 - accuracy: 0.9941 - val_loss: 0.0159 - val_accuracy: 0.9565
# Epoch 38/40
# 32/32 [==============================] - 13s 418ms/step - loss: 0.0349 - accuracy: 0.9927 - val_loss: 0.1313 - val_accuracy: 0.9348
# Epoch 39/40
# 32/32 [==============================] - 13s 411ms/step - loss: 0.0272 - accuracy: 0.9936 - val_loss: 0.6770 - val_accuracy: 0.9348
# Epoch 40/40
# 32/32 [==============================] - 13s 412ms/step - loss: 0.0331 - accuracy: 0.9912 - val_loss: 0.0673 - val_accuracy: 0.9427

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
#Saving the model in locally for future use

model.save('3-conv-95.h5')

# %% [markdown]
# ### Evaluation of model using own data

# %%
#loading the saved model
import keras

model = keras.models.load_model('3-conv-95.h5')

# %%
#Specifying the path for the test data
import os

test_path = os.path.join('./gender_dataset_face/Test/')

# %%
#Loading each image from the folder and feeding it to the model for prediction

import numpy as np
import keras
from keras.preprocessing import image

IMG_SIZE = 150

for fn in os.listdir(test_path):
    img = image.load_img(test_path+fn, target_size=(IMG_SIZE, IMG_SIZE))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)

    images = np.vstack([x])
    classes = model.predict(images, batch_size=5)
    #print(classes[0])
    if classes[0]>0.5:
        print(fn + " is a woman")
    else:
        print(fn + " is a man")
# Out:
# female1.jpg is a woman
# female10.jpg is a woman
# female2.jpg is a man
# female3.jpg is a woman
# female4.jpg is a man
# female5.jpg is a man
# female6.jpg is a man
# female7.jpg is a woman
# female8.jpg is a woman
# female9.jpg is a woman
# man1.jpg is a man
# man10.jpg is a man
# man2.jpg is a man
# man3.jpg is a man
# man4.jpg is a man
# man5.JPG is a man
# man6.jpg is a man
# man7.jpg is a man
# man8.jpg is a man
# man9.jpeg is a man

# %%
#Plotting the images
import matplotlib.pyplot as plt

img = image.load_img(test_path+'female6.jpg')
plt.imshow(img)
plt.show()
